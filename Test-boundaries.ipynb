# %%
import numpy as np
from bokeh.plotting import figure 
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9b0f77e5-e276-4ab3-bde6-ae64d745521d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Exponential

# %%
x1 = np.linspace(0, 160, 100)
y1 = np.exp(x / 50)
y2 = -np.exp(x / 50)

p1 = figure(plot_width=640, plot_height=480)
p1.line(x1, y1, line_width=30, line_color='black')
p1.line(x1, y2, line_width=30, line_color='black')
p1.line([0, 0], [-2.5, 2.5], line_width=5, line_color='black')
p1.xaxis.visible = False
p1.yaxis.visible = False
p1.toolbar.logo = None
# p1.toolbar_location = None
p1.xgrid.visible = False
p1.ygrid.visible = False
show(p1)
# Out:
#   <div class="bk-root" id="20d4514b-85fd-4144-bc83-374712e3004d"></div>

# %% [markdown]
# ### Parabolic

# %%
x1 = np.linspace(0, 160, 100)
y1 = 9*np.sqrt(x1)

p1 = figure(plot_width=640, plot_height=480)
p1.line(x1, y1, line_width=30, line_color='black')
p1.line(x1, -y1, line_width=30, line_color='black')
p1.xaxis.visible = False
p1.yaxis.visible = False
p1.toolbar.logo = None
# p1.toolbar_location = None
p1.xgrid.visible = False
p1.ygrid.visible = False
show(p1)
# Out:
#   <div class="bk-root" id="888237d5-dfa0-4abe-9b40-84f4c835d042"></div>

# %% [markdown]
# ### Linear

# %%
x1 = np.linspace(0, 160, 100)
y1 = x1

p1 = figure(plot_width=640, plot_height=480)
p1.line(x1, y1, line_width=30, line_color='black')
p1.line(x1, -y1, line_width=30, line_color='black')
p1.xaxis.visible = False
p1.yaxis.visible = False
p1.toolbar.logo = None
# p1.toolbar_location = None
p1.xgrid.visible = False
p1.ygrid.visible = False
show(p1)
# Out:
#   <div class="bk-root" id="22866f37-a8e8-40c4-93e9-99ce3ee4bceb"></div>
